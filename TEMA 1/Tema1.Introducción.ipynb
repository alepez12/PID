# %%
import cv2
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en escala de grises
imagen = cv2.imread('flores_amarillas.jpg', cv2.IMREAD_GRAYSCALE)

# 2️⃣ Ver el tipo de dato de la imagen
print(f"Tipo de dato de la imagen: {type(imagen)}")  # Tipo de la variable
print(f"Shape de la imagen: {imagen.shape}")  # Dimensiones (alto, ancho)
print(f"Tipo de datos de los píxeles: {imagen.dtype}")  # Tipo de datos (normalmente uint8)

# 3️⃣ Visualizar la imagen con OpenCV
cv2.imshow('Imagen en Escala de Grises', imagen)
cv2.waitKey(0)  # Esperar a que se presione una tecla
cv2.destroyAllWindows()  # Cerrar la ventana

# 4️⃣ Visualizar la imagen con Matplotlib
plt.imshow(imagen, cmap='gray')  # cmap='gray' para respetar los tonos de gris
plt.axis('off')  # Ocultar ejes
plt.title("Imagen en Escala de Grises")  # Título opcional
plt.show()
# Out:
# Tipo de dato de la imagen: <class 'numpy.ndarray'>
# Shape de la imagen: (675, 1200)
# Tipo de datos de los píxeles: uint8
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/ale/Documentos/PID/venv/lib/python3.12/site-packages/cv2/qt/plugins"

# %%
import cv2
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en color
imagen = cv2.imread('flores_amarillas.jpg')  # Se carga en formato BGR por defecto

# 2️⃣ Separar los canales de la imagen
B, G, R = cv2.split(imagen)  # OpenCV usa BGR, no RGB

# 3️⃣ Visualizar los canales por separado con Matplotlib
fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Imagen original (Convertimos de BGR a RGB para que Matplotlib la muestre correctamente)
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
axs[0].imshow(imagen_rgb)
axs[0].set_title('Imagen Original (RGB)')
axs[0].axis('off')

# Canal Azul (B)
axs[1].imshow(B, cmap='Blues')  
axs[1].set_title('Canal Azul (B)')
axs[1].axis('off')

# Canal Verde (G)
axs[2].imshow(G, cmap='Greens')  
axs[2].set_title('Canal Verde (G)')
axs[2].axis('off')

# Canal Rojo (R)
axs[3].imshow(R, cmap='Reds')  
axs[3].set_title('Canal Rojo (R)')
axs[3].axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en color
imagen = cv2.imread('flores_amarillas.jpg')  # OpenCV carga en formato BGR

# 2️⃣ Separar los canales B, G, R
B, G, R = cv2.split(imagen)

# 3️⃣ Aplicar la fórmula manualmente para convertir a escala de grises
imagen_gris_manual = (0.299 * R + 0.587 * G + 0.114 * B).astype(np.uint8)

# 4️⃣ Convertir la imagen a escala de grises directamente con OpenCV
imagen_gris_opencv = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

# 5️⃣ Comparar las dos imágenes
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Imagen original en RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
axs[0].imshow(imagen_rgb)
axs[0].set_title('Imagen Original (RGB)')
axs[0].axis('off')

# Imagen en escala de grises (Método Manual)
axs[1].imshow(imagen_gris_manual, cmap='gray')
axs[1].set_title('Escala de Grises - Método Manual')
axs[1].axis('off')

# Imagen en escala de grises (OpenCV)
axs[2].imshow(imagen_gris_opencv, cmap='gray')
axs[2].set_title('Escala de Grises - OpenCV')
axs[2].axis('off')

plt.show()

# 6️⃣ Comparar si las imágenes son iguales
iguales = np.array_equal(imagen_gris_manual, imagen_gris_opencv)
print(f"¿Las imágenes son iguales? {iguales}")
# Out:
# ¿Las imágenes son iguales? False

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en escala de grises
imagen = cv2.imread('flores_amarillas.jpg', cv2.IMREAD_GRAYSCALE)

# 2️⃣ Calcular el histograma
histograma = cv2.calcHist([imagen], [0], None, [256], [0, 256])

# 3️⃣ Visualizar la imagen y su histograma
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Mostrar la imagen en escala de grises
axs[0].imshow(imagen, cmap='gray')
axs[0].set_title('Imagen en Escala de Grises')
axs[0].axis('off')

# Mostrar el histograma
axs[1].plot(histograma, color='black')
axs[1].set_title('Histograma de Intensidad')
axs[1].set_xlabel('Valor de píxel')
axs[1].set_ylabel('Frecuencia')
axs[1].grid()

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en escala de grises
imagen = cv2.imread('alto_contraste.jpeg', cv2.IMREAD_GRAYSCALE)

# 2️⃣ Definir los parámetros de transformación
alpha = 155/255  # Factor de contraste (>1 aumenta contraste, <1 lo reduce)
beta = 100    # Factor de brillo (>0 aclara, <0 oscurece)

# 3️⃣ Aplicar la transformación lineal: T(r) = α * r + β
imagen_transformada = cv2.convertScaleAbs(imagen, alpha=alpha, beta=beta)

# 4️⃣ Visualizar la imagen original y la transformada
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Imagen original
axs[0].imshow(imagen, cmap='gray')
axs[0].set_title('Imagen Original')
axs[0].axis('off')

# Imagen transformada
axs[1].imshow(imagen_transformada, cmap='gray')
axs[1].set_title(f'Imagen Transformada (α={alpha}, β={beta})')
axs[1].axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 1️⃣ Cargar la imagen en escala de grises
imagen = cv2.imread('imagen.jpg', cv2.IMREAD_GRAYSCALE)

# 2️⃣ Calcular la constante 'c' para normalizar la imagen a 255
c = 255 / np.log(1 + np.max(imagen))

# 3️⃣ Aplicar la transformación logarítmica: T(r) = c * log(1 + r)
imagen_log = c * np.log(1 + imagen.astype(np.float32))

# 4️⃣ Normalizar la imagen y convertir a uint8
imagen_log = np.clip(imagen_log, 0, 255).astype(np.uint8)

# 5️⃣ Visualizar las imágenes
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Imagen original
axs[0].imshow(imagen, cmap='gray')
axs[0].set_title('Imagen Original')
axs[0].axis('off')

# Imagen transformada
axs[1].imshow(imagen_log, cmap='gray')
axs[1].set_title('Transformación Logarítmica')
axs[1].axis('off')

plt.show()
# Out:
# [ WARN:0@5.427] global loadsave.cpp:268 findDecoder imread_('imagen.jpg'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 9
#       6 imagen = cv2.imread('imagen.jpg', cv2.IMREAD_GRAYSCALE)
#       8 # 2️⃣ Calcular la constante 'c' para normalizar la imagen a 255
# ----> 9 c = 255 / np.log(1 + np.max(imagen))
#      11 # 3️⃣ Aplicar la transformación logarítmica: T(r) = c * log(1 + r)
#      12 imagen_log = c * np.log(1 + imagen.astype(np.float32))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'
